# %% [markdown]
# # 機械学習の応用
# 機械学習の応用として、映っている物体の検出・画像の分類などの画像処理が行われる。

# %% [markdown]
# ## 必要なライブラリー
# - Pillow - Python Image Libraryから派生した画像ファイルをあつかうためのファイル

# %%
# !pip install pillow

# %%
# Pillowを用いた画像処理

# %%
from PIL import Image
sample = Image.open("splash-7985598_960_720.jpg")

print(type(sample))
sample
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x719>

# %%
#　画像の基本データ

#サイズ
print(sample.size)
#形式
print(sample.format)
#モード
print(sample.mode)
# Out:
# (960, 719)
# JPEG
# RGB

# %%
#グレイスケール
sample.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=960x719>
